# %% [markdown]
# <a href="https://colab.research.google.com/github/sstankala/scratch_pad/blob/python/googlecolab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import ai
response = ai.generate_text(input("Your Question?\n"))
print(f'Google AI response:\n' + response)
# Out:
# Your Question?
# What is capital of India
# Google AI response:
# The capital of India is **New Delhi**.
